# %%
from Fr_Shorts import *
from Uk_Shorts import *
from Ge_Shorts import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### French Shorts

# %%
get_french_database()
t.sleep(3)
get_french_shorts_online()
t.sleep(3)
df = shorts_fr(first_time=False, N_caractères_noms = 18)
df
# Out:
# Launching...
# Launching...
# 8
# Nombre de shorts téléchargés: 9
# TEMPS D'EXEC : 0:00:29.276243, les Shorts ont bien été enregistrés
# Short n°1.pdf
# al persons may also register a complaint concerning the processing of theirdata with the CNIL.2024E991831QUBE RESEARCH & TECHNOLOGIESLIMITEDSARTORIUS STEDIM BIOTECHFR00131540020.502024-08-19FR0013154002 - DPC9918312024-08-16
# o register a complaint concerning the processing of theirdata with the CNIL.2024E991831QUBE RESEARCH & TECHNOLOGIESLIMITEDSARTORIUS STEDIM BIOTECHFR00131540020.502024-08-19FR0013154002 - DPC9918312024-08-16
# FR0013154002
# Le nom de l'issuer est:['SARTORIUS STEDIM B']
# on a bien changé l'issuer
# SARTORIUS STEDIM B
# 2024-08-16
# ['Detenteur de la position courte nette', 'Legal Entity Identifier detenteur', 'Emetteur / issuer', 'Ratio', 'code ISIN', 'Date de debut position', 'Date de debut de publication position', 'Date de fin de publication position']
# QUBE RESEARCH & TECHNOLOGIES LIMITED
# ...

# %% [markdown]
# ### UK shorts

# %%
get_uk_database()
report_short_uk()
# Out:
# Launching...
# <style type="text/css">
# ...

# %% [markdown]
# ### GERMANY shorts

# %%
german_shorts()
# Out:
# <style type="text/css">
# ...
